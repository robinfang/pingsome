# %%
import pandas as pd
import matplotlib
import tables
df = pd.read_hdf("result.h5")

# %%
df
# Out:
#                             t  110.242.68.66  124.16.137.65  159.226.8.7  \
# 0  2023-01-05 16:16:42.343066      10.061979       2.046824     2.075434
# 1  2023-01-05 16:16:46.409801       9.016037       2.014160     1.993179
# 2  2023-01-05 16:16:50.459683      10.146618       1.999617     2.074718
# 3  2023-01-05 16:16:54.514741      10.149240       1.998186     1.993656
# 4  2023-01-05 16:16:58.571427      10.002613       3.000021     3.001690
# ..                        ...            ...            ...          ...
# 69 2023-01-05 16:21:22.104675       9.967327       3.014803     2.999783
# 70 2023-01-05 16:21:26.161382       8.032322       3.036499     2.961874
# 71 2023-01-05 16:21:30.208314       8.998632       0.998020     1.998425
# 72 2023-01-05 16:21:34.261988       8.971214       1.044273     1.989126
# 73 2023-01-05 16:21:38.310937       9.985209       2.025127     2.998590
#
#     114.114.114.114
# 0         28.019667
# 1         27.833462
# 2         28.454304
# ...

# %%
df.plot(x="t")
# Out:
# <AxesSubplot: xlabel='t'>
